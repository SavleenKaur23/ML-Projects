# %% [markdown]
# ***Segmenting an image using K Means Clustering***
#
# *Partitioning a digital image into multiple segments*

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.datasets import load_sample_image
#load_sample_image dataset from scikit learn consists of numpy array of a single sample image

#Data plotting and visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from scipy.stats import mode
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ##### Loading a sample flower image from load_sample_image scikit learn dataset

# %%
flower = load_sample_image("flower.jpg")
ax = plt.axes(xticks = [], yticks = [])
ax.imshow(flower)

# %%
flower.shape
#3 channels in image i.e RGB
# Out:
# (427, 640, 3)

# %%
data = flower/255.0  #all pixels are scaled b/w 0 and 1(255) (to reduce noise in the data)
data = data.reshape(427 * 640, 3) #transformation o flattened data
data.shape
# Out:
# (273280, 3)

# %% [markdown]
# ##### Using K Means Clustering

# %%
kmeans = KMeans(3)  #3 clusters
kmeans.fit(data)
new_colors = kmeans.cluster_centers_[kmeans.predict(data)]

# %%
new_colors.shape
# Out:
# (273280, 3)

# %%
flower_recolored = new_colors.reshape(flower.shape)
fig,ax = plt.subplots(1,2,figsize=(16,6),
                     subplot_kw=dict(xticks=[],yticks=[]))
fig.subplots_adjust(wspace=0.05)
ax[0].imshow(flower)
ax[0].set_title("Original Image", size = 16)
ax[1].imshow(flower_recolored)
ax[1].set_title("3 Colored Image", size = 16)
# Out:
# Text(0.5, 1.0, '3 Colored Image')

# %% [markdown]
# *More the number of clusters, better the clarity of the image*
